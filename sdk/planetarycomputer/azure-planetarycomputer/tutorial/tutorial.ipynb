# %%
# !az login
from azure.identity import AzureCliCredential

credential = AzureCliCredential()

# %%
from azure.identity import AzureCliCredential
from azure.planetarycomputer import MicrosoftPlanetaryComputerProClient
from datetime import datetime, timedelta, timezone
import json, time, random, string
from PIL import Image
from io import BytesIO
import requests

# Setup GeoCatalog client
credential = AzureCliCredential()
endpoint = "https://testcatalog-3480.a5cwawdkcbdfgtcw.uksouth.geocatalog.spatio-ppe.azure-test.net"
client = MicrosoftPlanetaryComputerProClient(endpoint=endpoint, credential=credential)

# %%
# !az account show
# Out:
# {
#   "environmentName": "AzureCloud",
#   "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#   "id": "ac9a1867-7476-4346-bf8b-968370fe212c",
#   "isDefault": true,
#   "managedByTenants": [],
#   "name": "aopc-ms-test-data",
#   "state": "Enabled",
#   "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#   "user": {
#     "name": "haseidfa@microsoft.com",
#     "type": "user"
#   }
# }
